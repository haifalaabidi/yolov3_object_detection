# %%
# !nvidia-smi
# Out:
# Sun Dec 24 23:28:41 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8              13W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/yolo-data-extraction-20231224T203054Z-001.zip" -d "/content/drive/MyDrive"
# Out:
# Archive:  /content/drive/MyDrive/yolo-data-extraction-20231224T203054Z-001.zip
#   inflating: /content/drive/MyDrive/yolo-data-extraction/custom_dataset/test.txt
#   inflating: /content/drive/MyDrive/yolo-data-extraction/custom_dataset/train.txt
#   inflating: /content/drive/MyDrive/yolo-data-extraction/custom_dataset/classes.names
#   inflating: /content/drive/MyDrive/yolo-data-extraction/custom_dataset/Interests_1f0ea18f-bba7-4d42-9a56-620ec92e830d.txt
#   inflating: /content/drive/MyDrive/yolo-data-extraction/custom_dataset/classes.txt
#   inflating: /content/drive/MyDrive/yolo-data-extraction/custom_dataset/Interests_1f0ea18f-bba7-4d42-9a56-620ec92e830d.jpg
#   inflating: /content/drive/MyDrive/yolo-data-extraction/custom_dataset/Name_1f0ea18f-bba7-4d42-9a56-620ec92e830d.jpg
#   inflating: /content/drive/MyDrive/yolo-data-extraction/custom_dataset/Languages_1f0ea18f-bba7-4d42-9a56-620ec92e830d.jpg
# ...

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/yolo-data-extraction/darknet'
# Out:
# Cloning into '/content/drive/MyDrive/yolo-data-extraction/darknet'...
# remote: Enumerating objects: 15833, done.
# remote: Total 15833 (delta 0), reused 0 (delta 0), pack-reused 15833
# Receiving objects: 100% (15833/15833), 14.39 MiB | 12.44 MiB/s, done.
# Resolving deltas: 100% (10666/10666), done.
# Updating files: 100% (2056/2056), done.

# %%
# %cd /content/drive/MyDrive/yolo-data-extraction/darknet
# Out:
# /content/drive/MyDrive/yolo-data-extraction/darknet

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#   253 |                 int n = _write(client, outputbuf, outlen);
#       |                     ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ...

# %%
# %cd /content/drive/MyDrive/yolo-data-extraction
# Out:
# /content/drive/MyDrive/yolo-data-extraction

# %%
# !darknet/darknet detector train custom_dataset/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
#  GPU isn't used
#  OpenCV isn't used - data augmentation will be slow
# yolov3_custom
# mini_batch = 4, batch = 32, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
# ...
